# %% [markdown]
# # MÓDULO 7: Fundamentos del Deep Learning
#
#
# - Nombre alumno: Sebastián Menares Arriaza

# %% [markdown]
# # Tema : Fundamentos del Deep Learning

# %% [markdown]
# Para este ejercicio usted debe:
# 1. Defina el modelo de Keras.
# 2. Compile el modelo de Keras.
# 3. Compatible con el modelo Keras.
# 4. Evalúe el modelo de Keras.
# 5. Juntelo todo junto.
# 6. Hacer predicciones y conclusiones.
#
# Recuerde que debe tener instalado:
#
# • Tiene SciPy (incluido NumPy) instalado y configurado.
#
# • Tiene Keras y un backend (Theano o TensorFlow) instalado y configurado.
#
# Cree un nuevo archivo llamado
#
# Mi_primera_red_keras_NOMBRE1_APELLIDO1_NOMBRE2_APELLIDO2.ipynb (.py).
#
# Adjunto encontrará la base de datos y los detalles del set de datos.

# %%
# Primera Red Neuronal con Keras
import pandas as pd
import numpy as np

from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# prompt: cargar drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd  # Importación de pandas para procesamiento de datos

ruta = '/content/drive/MyDrive/CienciaDatos/2024/M7/Data/diabetes.csv'
# Lectura del archivo CSV
data = pd.read_csv(ruta)

# Visualización de las primeras filas del DataFrame
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df = data.copy()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# dividido en variables de entrada (X) y salida (y)
X = df.iloc[:,0:8].values
y = df['Outcome'].values

# %% [markdown]
# ## 1 Defina le Modelo Keras

# %%
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ##2 Compile el Modelo Keras

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ##3 Entrenar el Modelo Keras

# %%
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 6.3969 - accuracy: 0.5352
# Epoch 2/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.8926 - accuracy: 0.6198
# Epoch 3/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.1763 - accuracy: 0.5885
# Epoch 4/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.9922 - accuracy: 0.6068
# Epoch 5/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8909 - accuracy: 0.6029
# Epoch 6/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8497 - accuracy: 0.6263
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8020 - accuracy: 0.6198
# Epoch 8/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7728 - accuracy: 0.6211
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7363 - accuracy: 0.6107
# Epoch 10/150
# ...

# %%
'''
#En caso de tener error en el código anterior, puedes probar con este código.
# Entrene el Modelo Keras sin la barra de progreso
model.fit(X, y, epochs=150, batch_size=10, verbose=0)
# Evalue el modelo Keras
_, accuracy = model.evaluate(X, y, verbose=0)'''
# Out:
# '\n#En caso de tener error en el código anterior, puedes probar con este código.\n# Entrene el Modelo Keras sin la barra de progreso\nmodel.fit(X, y, epochs=150, batch_size=10, verbose=0)\n# Evalue el modelo Keras\n_, accuracy = model.evaluate(X, y, verbose=0)'

# %% [markdown]
# ##4 Evalue el Modelo Keras

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5000 - accuracy: 0.7617
# Accuracy: 76.17

# %% [markdown]
# ##5 Junte todo

# %%
# Primera Red Neuronal con Keras
import pandas as pd
import numpy as np

from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#Cargar el Dataset
df = data.copy()

# dividido en variables de entrada (X) y salida (y)
X= df.iloc[:,0:8].values
y=df['Outcome'].values
# Defina le Modelo Keras
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile el Modelo Keras
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Entrenar el Modelo Keras
model.fit(X, y, epochs=150, batch_size=10)
# Evalue el Modelo Keras
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 3.0706 - accuracy: 0.4531
# Epoch 2/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.9028 - accuracy: 0.5990
# Epoch 3/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7444 - accuracy: 0.6341
# Epoch 4/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7071 - accuracy: 0.6484
# Epoch 5/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.6536
# Epoch 6/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6757 - accuracy: 0.6562
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6623 - accuracy: 0.6536
# Epoch 8/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6534 - accuracy: 0.6745
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.6602
# Epoch 10/150
# ...

# %% [markdown]
# ##6 Hacer predicciones y conclusiones.

# %%
# Hacer predicciones
predictions = model.predict(X)

# Mostrar las primeras 5 predicciones
print(predictions[:10])
# Out:
# 24/24 [==============================] - 0s 7ms/step
# [[0.7030335 ]
#  [0.40861106]
#  [0.85265404]
#  [0.16988982]
#  [0.5263654 ]
#  [0.41589278]
#  [0.2736568 ]
#  [0.77790993]
#  [0.5263654 ]
#  [0.38830236]]

# %%
# Primera Red Neuronal con Keras
import pandas as pd
import numpy as np
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Cargar el Dataset
df = data.copy()

# Dividido en variables de entrada (X) y salida (y)
X = df.iloc[:, 0:8].values
y = df['Outcome'].values

# Definir el Modelo Keras
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compilar el Modelo Keras
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Entrenar el Modelo Keras
model.fit(X, y, epochs=150, batch_size=10)

# Evaluar el Modelo Keras
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy * 100))
# Out:
# Epoch 1/150
# 77/77 [==============================] - 2s 4ms/step - loss: 7.9173 - accuracy: 0.6250
# Epoch 2/150
# 77/77 [==============================] - 0s 4ms/step - loss: 1.7056 - accuracy: 0.5703
# Epoch 3/150
# 77/77 [==============================] - 0s 5ms/step - loss: 1.3655 - accuracy: 0.5690
# Epoch 4/150
# 77/77 [==============================] - 0s 6ms/step - loss: 1.2230 - accuracy: 0.5547
# Epoch 5/150
# 77/77 [==============================] - 0s 5ms/step - loss: 1.0477 - accuracy: 0.5404
# Epoch 6/150
# 77/77 [==============================] - 0s 5ms/step - loss: 0.9077 - accuracy: 0.5781
# Epoch 7/150
# 77/77 [==============================] - 0s 5ms/step - loss: 0.7928 - accuracy: 0.6237
# Epoch 8/150
# 77/77 [==============================] - 0s 5ms/step - loss: 0.7167 - accuracy: 0.6589
# Epoch 9/150
# 77/77 [==============================] - 0s 4ms/step - loss: 0.7036 - accuracy: 0.6602
# Epoch 10/150
# ...

# %%
# Hacer predicciones
y_pred = model.predict(X)

# Convertir las predicciones en etiquetas de clase (0 o 1)
y_pred_classes = np.round(y_pred)

# Imprimir el reporte de clasificación
from sklearn.metrics import classification_report
print(classification_report(y, y_pred_classes))

# Imprimir las métricas
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)


# Agregar mensaje de conclusiones basadas en los resultados
if accuracy >= 0.80:
    print("El modelo ha alcanzado una precisión aceptable en la clasificación.")
elif accuracy >= 0.70:
    print("El modelo ha alcanzado una precisión moderada en la clasificación.")
else:
    print("El modelo tiene un rendimiento bajo en la clasificación y puede requerir ajustes adicionales.")
# Out:
# 24/24 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83       500
#            1       0.74      0.50      0.60       268
#
#     accuracy                           0.76       768
#    macro avg       0.75      0.70      0.71       768
# weighted avg       0.76      0.76      0.75       768
#
# Accuracy: 0.7630208333333334
# Precision: 0.7362637362637363
# Recall: 0.5
# El modelo ha alcanzado una precisión moderada en la clasificación.

# %%
# Análisis de predicciones
# Por ejemplo, puedes imprimir algunas predicciones y sus etiquetas verdaderas para analizar dónde el modelo acierta o falla.
print("Ejemplos de predicciones y etiquetas verdaderas:")
for i in range(10):
    print("Predicción:", y_pred_classes[i], "Etiqueta verdadera:", y[i])
# Out:
# Ejemplos de predicciones y etiquetas verdaderas:
# Predicción: [1.] Etiqueta verdadera: 1
# Predicción: [0.] Etiqueta verdadera: 0
# Predicción: [1.] Etiqueta verdadera: 1
# Predicción: [0.] Etiqueta verdadera: 0
# Predicción: [1.] Etiqueta verdadera: 1
# Predicción: [0.] Etiqueta verdadera: 0
# Predicción: [0.] Etiqueta verdadera: 1
# Predicción: [1.] Etiqueta verdadera: 0
# Predicción: [1.] Etiqueta verdadera: 1
# Predicción: [0.] Etiqueta verdadera: 1

# %% [markdown]
# # Recursos Bibliográficos:
#
# [1] [Qué es el Deep Learning](https://www.youtube.com/watch?v=s0SbvGiG28w)
#
# [2] [Diferencias: Machine learning, Deep learning e Inteligencia artificial](https://www.youtube.com/watch?v=THrgrb-3lsM)
#
# [3] [Inteligencia artificial](https://www.simplilearn.com/tutorials/artificial-intelligence-tutorial/ai-vs-machine-learning-vs-deep-learning#:~:text=Artificial%20Intelligence%20is%20the%20concept,algorithms%20to%20train%20a%20model.)
#
# [4] [Neural netwoks](https://www.ibm.com/cloud/learn/neural-networks)
#
# [5] [Aplicaciones de Redes neuronales](https://www.datacentric.es/blog/insight/red-neuronal-artificial-aplicaciones/)
